# %%
from typing import List, Optional

# def next_smaller_elements(n:int, nums: List[int]) -> Optional[List]:
    
#     if n in [0, 1]:
#         return nums
#     result = []
    
#     for i in range(n):
#         inserted = False
#         for j in range(i+1, n):
#             if nums[i] < nums[j]:
#                 continue
            
#             inserted = True
#             if j == n-1 and nums[i] < nums[j]:
#                 result.append(-1)
#             else:
#                 result.append(nums[j])
#                 break
#         if not inserted:
#             result.append(-1)
#     # result.append(-1)
#     return result


def next_smaller_elements(arr):
    n = len(arr)
    result = [-1] * n 
    stack = []


    for i in range(n - 1, -1, -1):

        while stack and stack[-1] >= arr[i]:
            stack.pop()
        
        if stack:
            result[i] = stack[-1]
        
        stack.append(arr[i])
    
    return result

# %%
# nums = [4, 5, 2, 10, 8]
nums = [1, 3, 4, 2, 5, 1, 0]
print(next_smaller_elements(7, nums))
# Out:
# [0, 2, 2, 1, 1, 0, -1]
